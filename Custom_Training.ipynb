# %% [markdown]
# <a href="https://colab.research.google.com/github/thedanoprean/poker-hand-recognizer/blob/master/Custom_Training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO

# %%
# !yolo task=detect mode=train model=yolov8l.pt data='../content/drive/MyDrive/Datasets/PokerHands/data.yaml' epochs=30 imgsz=640
# Out:
# ...
# 100% 83.7M/83.7M [00:02<00:00, 43.6MB/s]
# Ultralytics YOLOv8.0.166 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# ...
